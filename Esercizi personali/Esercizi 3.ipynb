# %%
#Esercizio 1 - Operatori aritmetici

a = 17
b = 5

a + b
a - b
a * b
a / b
a % b
a ** b
# Out:
# 22

# %%
#Esercizio 2 - Operatori aritmetici

sec = 3725

ore = sec // 3600
print (ore)

min = (sec - 3600) // 60
print (min)

sectot = (sec - 3600) - (2 * 60)
# Out:
# 1
# 2
