# %%
#Esercizio 1 - LISTE

clienti = ["nike", "adidas", "puma"]

print(clienti)
print(clienti[0])
print(clienti[2])

clienti.append("reebok")
clienti[1] = "under armour"
print(clienti)
len(clienti)
# Out:
# ['nike', 'adidas', 'puma']
# nike
# puma
# ['nike', 'under armour', 'puma', 'reebok']
# 4

# %%
#Esercizio 2 - TUPLE

coordinate = (10, 20)

print(coordinate[0])
x, y = coordinate
print(x)
print(y)

coordinate[0] = 50
# Out:
# 10
# 10
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       7 print(x)
#       8 print(y)
# ---> 10 coordinate[0] = 50
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Esercizio 3 - DIZIONARI

cliente = {
    "nome": "Nike",
    "budget": 5000,         # ← virgola necessaria
    "settore": "sport",
    "attivo": True
}

print(cliente["nome"])
print(cliente.get("budget"))

cliente["budget"] = 3500

print(cliente.get("budget"))
# Out:
# Nike
# 5000
# 3500

# %%
#Esercizio 4 - SET
tags = {"ai", "marketing", "ai", "automation"}

print(tags)
# Out:
# {'marketing', 'ai', 'automation'}

# %%
#Esercizio AGENCY MODE

clienti = [
    {"nome": "Nike", "budget": 5000},
    {"nome": "Adidas", "budget": 3000},
    {"nome": "Puma", "budget": 2000}
]

print(clienti[0]["nome"])
print(clienti[1]["nome"])
print(clienti[2]["nome"])
print(clienti[2]["nome"])
# Out:
# Nike
# Adidas
# Puma
# Puma

# %%
#CHALLENGE 1

prompt_templates = [
    {"tipo": "email", "tono": "professionale"},
    {"tipo": "social", "tono": "informale"}
]

print(f'genera un contenuto {prompt_templates[0]["tipo"]} con tono {prompt_templates[0]["tono"]}')
# Out:
# genera un contenuto email con tono professionale
