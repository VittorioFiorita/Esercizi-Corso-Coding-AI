# %%
#Esercizio 1

nome = "marco"
eta = 28
lavoro ="web developer"

print(nome)
print(eta)
print(lavoro)
# Out:
# marco
# 28
# web developer

# %%
#Esercizio 2

nome = "marco"
eta = 28
lavoro ="web developer"

print("Mi chiamo " + nome + ", ho " + str(eta) + " anni e lavoro come " + lavoro)

print(f"Mi chiamo {nome}, ho {eta} anni e lavoro come {lavoro}")
# Out:
# Mi chiamo marco, ho 28 anni e lavoro come web developer
# Mi chiamo marco, ho 28 anni e lavoro come web developer

# %%
#Esercizio 3

print("Lui ha detto \"ciao\"")
# Out:
# Lui ha detto "ciao"

# %%
#Esercizio 4

prodotto = "scarpe running"
prezzo = 120

print(f"le {prodotto} costano {prezzo} euro")
# Out:
# le scarpe running costano 120 euro

# %%
#Esercizio Agency Mode

cliente = "Adidas"
prodotto = "sneakers"
target = "giovani sportivi"

print(f"stiamo creando una campagna per {cliente}, prodotto {prodotto}, target {target}")
# Out:
# stiamo creando una campagna per Adidas, prodotto sneakers, target giovani sportivi

# %%
#Challenge LEzione 1
